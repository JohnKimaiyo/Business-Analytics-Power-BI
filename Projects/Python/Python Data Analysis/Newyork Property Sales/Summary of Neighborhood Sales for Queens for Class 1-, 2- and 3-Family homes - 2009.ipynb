# %% [markdown]
# #  The Department of Finance (DOF) maintains records for all property sales in New York City EDA Analysis
# The Department of Finance (DOF) maintains records for all property sales in New York City, including sales of family homes in each borough. This list is a summary of neighborhood sales for Class 1-, 2- and 3-Family homes in Queens in 2009. Update Schedule: Annually

# %%
# import libraries
import pandas as pd
import numpy as np

# load data
newyork_homesales_df =  pd.read_csv(r"C:\Users\jki\Downloads\DOF__Summary_of_Neighborhood_Sales_for_Queens_for_Class_1-__2-_and_3-Family_homes_-_2009.csv")
newyork_homesales_df.head(5)
# Out:
#                 NEIGHBORHOOD                                 TYPE OF HOME  \
# 0  AIRPORT LA GUARDIA         01 ONE FAMILY HOMES
# 1  AIRPORT LA GUARDIA         02 TWO FAMILY HOMES
# 2  ARVERNE                    01 ONE FAMILY HOMES
# 3  ARVERNE                    02 TWO FAMILY HOMES
# 4  ARVERNE                    03 THREE FAMILY HOMES
#
#    TOTAL NO. OF PROPERTIES  NUMBER OF SALES  LOWEST SALE PRICE  \
# 0                       84                1           485000.0
# 1                       14                1           480000.0
# 2                      696               32           161000.0
# 3                     1528              112           160000.0
# 4                      137                6           165000.0
#
#    AVERAGE SALE PRICE  MEDIAN SALE PRICE  HIGHEST SALE PRICE
# 0            485000.0           485000.0            485000.0
# 1            480000.0           480000.0            480000.0
# 2            297194.0           310276.0            390291.0
# ...

# %%
# let check for missing values
missing_values = newyork_homesales_df.isna().sum()
print(missing_values)
# Out:
# NEIGHBORHOOD               0
# TYPE OF HOME               0
# TOTAL NO. OF PROPERTIES    0
# NUMBER OF SALES            0
# LOWEST SALE PRICE          0
# AVERAGE SALE PRICE         0
# MEDIAN SALE PRICE          0
# HIGHEST SALE PRICE         0
# dtype: int64

# %%
# let see if we have unwanted negative values
newyork_homesales_df.describe()
# Out:
#        TOTAL NO. OF PROPERTIES  NUMBER OF SALES  LOWEST SALE PRICE  \
# count               157.000000       157.000000       1.570000e+02
# mean               1757.802548        55.547771       2.759957e+05
# std                2017.457785        65.829952       1.567446e+05
# min                  10.000000         1.000000       1.500000e+05
# 25%                 311.000000         7.000000       1.610000e+05
# 50%                 957.000000        27.000000       2.250000e+05
# 75%                2634.000000        76.000000       3.295500e+05
# max               13561.000000       378.000000       1.065000e+06
#
#        AVERAGE SALE PRICE  MEDIAN SALE PRICE  HIGHEST SALE PRICE
# count        1.570000e+02       1.570000e+02        1.570000e+02
# mean         5.401625e+05       5.360515e+05        9.429312e+05
# std          1.689076e+05       1.668920e+05        5.492973e+05
# min          1.942600e+05       1.942600e+05        2.035200e+05
# ...

# %%
# let check for duplicate
newyork_homesales_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Length: 157, dtype: bool
